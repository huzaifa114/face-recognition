# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN

# %%
# face detection with mtcnn on a photograph

# load image from file
filename = 'images/test_1.jpg'
pixels = plt.imread(filename)

# create the detector, using default weights
detector = MTCNN()

# detect faces in the image
faces = detector.detect_faces(pixels)
for face in faces:
    print('\n')
    print(face)
# Out:
# {'box': [188, 67, 87, 118], 'confidence': 0.9973015189170837, 'keypoints': {'nose': [219, 142], 'mouth_right': [245, 157], 'right_eye': [250, 118], 'left_eye': [208, 109], 'mouth_left': [200, 147]}}
#
#
# {'box': [371, 80, 105, 138], 'confidence': 0.9763906002044678, 'keypoints': {'nose': [406, 166], 'mouth_right': [437, 187], 'right_eye': [440, 138], 'left_eye': [392, 134], 'mouth_left': [388, 184]}}

# %%
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = Rectangle((x, y), width, height, fill=False, color='red')
        # draw the box
        ax.add_patch(rect)
    # show the plot
    plt.show()

# %%
filename = 'images/test_1.jpg'
# load image from file
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %%
filename = 'images/th.jpeg'
# load image from file
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
draw_image_with_boxes(filename, faces)

# %%
# draw an image with detected objects
def draw_image_with_boxes_and_features(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = Rectangle((x, y), width, height, fill=False, color='red')
        # draw the box
        ax.add_patch(rect)
        # draw the dots
        for key, value in result['keypoints'].items():
            # create and draw dot
            dot = Circle(value, radius=2, color='red')
            ax.add_patch(dot)
    # show the plot
    plt.show()

# %%
filename = './images/look.jpeg'
# load image from file
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes_and_features(filename, faces)

# %%
# draw each face separately
def draw_faces(filename, result_list):
    # load plt image
    data = plt.imread(filename)
    # plot each face as a subplot
    for i in range(len(result_list)):
        # get coordinates
        x1, y1, width, height = result_list[i]['box']
        x2, y2 = x1 + width, y1 + height
        # define subplot
        plt.subplot(1, len(result_list), i+1)
        plt.axis('off')
        # plot face
        plt.imshow(data[y1:y2, x1:x2])
    # show the plot
    plt.show()

filename = './images/pic.jpeg'
# load image from file
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_faces(filename, faces)

# %%
# load image from file
filename = './images/pic.jpeg'
pixels = plt.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
for face in faces:
    print(face)
# Out:
# {'box': [390, 125, 40, 51], 'confidence': 0.9999933242797852, 'keypoints': {'nose': [407, 158], 'mouth_right': [420, 160], 'right_eye': [416, 145], 'left_eye': [399, 147], 'mouth_left': [401, 163]}}
# {'box': [112, 22, 24, 31], 'confidence': 0.999993085861206, 'keypoints': {'nose': [124, 39], 'mouth_right': [130, 45], 'right_eye': [130, 34], 'left_eye': [118, 34], 'mouth_left': [117, 44]}}
# {'box': [269, 29, 29, 35], 'confidence': 0.9999916553497314, 'keypoints': {'nose': [284, 50], 'mouth_right': [290, 55], 'right_eye': [291, 43], 'left_eye': [278, 42], 'mouth_left': [276, 54]}}
# {'box': [13, 119, 35, 44], 'confidence': 0.9999649524688721, 'keypoints': {'nose': [31, 145], 'mouth_right': [41, 149], 'right_eye': [38, 133], 'left_eye': [22, 137], 'mouth_left': [24, 153]}}
# {'box': [224, 8, 26, 35], 'confidence': 0.9999279975891113, 'keypoints': {'nose': [239, 30], 'mouth_right': [244, 34], 'right_eye': [245, 22], 'left_eye': [232, 22], 'mouth_left': [232, 34]}}
# {'box': [273, 82, 41, 53], 'confidence': 0.9998701810836792, 'keypoints': {'nose': [291, 113], 'mouth_right': [304, 118], 'right_eye': [301, 101], 'left_eye': [283, 103], 'mouth_left': [283, 120]}}
# {'box': [339, 0, 30, 27], 'confidence': 0.9998155236244202, 'keypoints': {'nose': [354, 13], 'mouth_right': [362, 17], 'right_eye': [362, 5], 'left_eye': [348, 4], 'mouth_left': [347, 17]}}
# {'box': [215, 65, 33, 45], 'confidence': 0.9997771382331848, 'keypoints': {'nose': [230, 92], 'mouth_right': [236, 101], 'right_eye': [241, 86], 'left_eye': [226, 81], 'mouth_left': [220, 96]}}
# {'box': [179, 37, 29, 36], 'confidence': 0.9996777772903442, 'keypoints': {'nose': [194, 59], 'mouth_right': [200, 65], 'right_eye': [201, 51], 'left_eye': [188, 50], 'mouth_left': [189, 65]}}
# {'box': [170, 113, 38, 49], 'confidence': 0.9995800852775574, 'keypoints': {'nose': [190, 144], 'mouth_right': [201, 146], 'right_eye': [198, 130], 'left_eye': [180, 133], 'mouth_left': [181, 149]}}
# {'box': [402, 51, 33, 43], 'confidence': 0.9995207786560059, 'keypoints': {'nose': [416, 79], 'mouth_right': [425, 83], 'right_eye': [425, 69], 'left_eye': [409, 69], 'mouth_left': [410, 83]}}
# {'box': [66, 49, 25, 34], 'confidence': 0.9985902905464172, 'keypoints': {'nose': [77, 69], 'mouth_right': [84, 74], 'right_eye': [84, 62], 'left_eye': [72, 62], 'mouth_left': [71, 74]}}
# {'box': [157, 2, 24, 30], 'confidence': 0.9985426664352417, 'keypoints': {'nose': [170, 19], 'mouth_right': [174, 25], 'right_eye': [176, 14], 'left_eye': [165, 12], 'mouth_left': [162, 22]}}
# {'box': [152, 55, 28, 41], 'confidence': 0.9985406398773193, 'keypoints': {'nose': [166, 78], 'mouth_right': [171, 86], 'right_eye': [174, 73], 'left_eye': [160, 70], 'mouth_left': [157, 83]}}
# {'box': [93, 80, 33, 45], 'confidence': 0.9983592629432678, 'keypoints': {'nose': [110, 107], 'mouth_right': [118, 113], 'right_eye': [118, 98], 'left_eye': [102, 97], 'mouth_left': [100, 111]}}
# {'box': [23, 33, 27, 33], 'confidence': 0.998040497303009, 'keypoints': {'nose': [39, 54], 'mouth_right': [46, 57], 'right_eye': [44, 45], 'left_eye': [31, 47], 'mouth_left': [32, 59]}}
# {'box': [317, 47, 31, 41], 'confidence': 0.9883424639701843, 'keypoints': {'nose': [332, 74], 'mouth_right': [341, 77], 'right_eye': [340, 64], 'left_eye': [325, 64], 'mouth_left': [324, 77]}}
# {'box': [442, 24, 31, 43], 'confidence': 0.9840447902679443, 'keypoints': {'nose': [459, 47], 'mouth_right': [465, 56], 'right_eye': [467, 41], 'left_eye': [452, 38], 'mouth_left': [449, 55]}}
